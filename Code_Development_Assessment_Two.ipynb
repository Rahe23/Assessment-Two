# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahe23/Assessment-Two/blob/main/Code_Development_Assessment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import Necessary Libraries

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create A Connection

# %%
# Connect to the SQLite database
connection = sqlite3.connect('/content/AUS_energy_sqlite3.db')

# %% [markdown]
# *   Made  new connection object, as well as a new file called AUS_energy_sqlite3 3.db  in the directory.

# %% [markdown]
# ####  Create a cursor objectcreated a database connection object, our next task is to create a cursor object. A cursor object allows us to execute SQL queries against a database. A cursor acts a middleware between a connection and SQL query

# %%
cur = connection.cursor() #something like 'row' returned from a table

# %% [markdown]
# ### View Schema

# %%
sql='''
SELECT name FROM sqlite_master WHERE type='table';
'''
cur.execute(sql)
cur.fetchall()
# Out:
# [('AUS_energy',)]

# %% [markdown]
# ### Now Get Details On A Table

# %%
sql='''
PRAGMA table_info('AUS_energy');
'''
cur.execute(sql)
cur.fetchall()
# Out:
# [(0, 'Year', 'TEXT', 0, None, 0),
#  (1, 'State', 'TEXT', 0, None, 0),
#  (2, 'Coal (PJ)', 'REAL', 0, None, 0),
#  (3, 'Oil (PJ)', 'REAL', 0, None, 0),
#  (4, 'Gas (PJ)', 'REAL', 0, None, 0),
#  (5, 'Renewables (PJ)', 'REAL', 0, None, 0),
#  (6, 'Population', 'INTEGER', 0, None, 0),
#  (7, 'GSP ($ million)', 'INTEGER', 0, None, 0)]

# %% [markdown]
# ### Fetching Data

# %%
sql = '''
SELECT * FROM AUS_energy;
'''
rows = cur.execute(sql)
for row in rows:
  print(row)
rows = cur.execute(sql)
for row in rows:
  print(row)
# Out:
# ('2008-09', 'WA', 132.9, 294.3, 474.7, 15.6, 2240250, 244695)
# ('2008-09', 'NSW', 800.9, 587.5, 131.6, 54.7, 7408540, 530532)
# ('2008-09', 'VIC', 695.3, 432.9, 273.5, 33.6, 5371934, 368579)
# ('2008-09', 'QLD', 629.2, 469.5, 187.9, 77.4, 4328771, 284526)
# ('2008-09', 'SA', 80.2, 120.2, 134.0, 21.2, 1608902, 100174)
# ('2008-09', 'TAS', 12.4, 41.6, 11.2, 37.1, 504353, 28165)
# ('2008-09', 'NT', '', 54.8, 39.9, 0.4, 226027, 19562)
# ('2009-10', 'WA', 125.6, 290.0, 474.9, 14.6, 2290845, 259326)
# ('2009-10', 'NSW', 771.8, 638.9, 148.7, 63.8, 7506058, 539670)
# ('2009-10', 'VIC', 688.7, 448.4, 263.5, 36.0, 5461101, 372276)
# ('2009-10', 'QLD', 547.5, 466.9, 195.8, 107.4, 4404744, 290556)
# ('2009-10', 'SA', 79.7, 120.5, 119.5, 20.4, 1627322, 102303)
# ('2009-10', 'TAS', 11.5, 41.5, 13.6, 40.0, 508847, 28402)
# ('2009-10', 'NT', '', 51.9, 42.0, 0.5, 229778, 19469)
# ('2010-11', 'WA', 130.6, 341.5, 494.9, 15.3, 2353409, 271336)
# ...

# %% [markdown]
# ### Fetching Many Method
# Here  Take A look at how to select data with SQLite in Python.

# %%
sql = '''
SELECT * FROM AUS_energy;
'''
cur.execute(sql)
four_results = cur.fetchmany(4)
print(four_results)
# Out:
# [('2008-09', 'WA', 132.9, 294.3, 474.7, 15.6, 2240250, 244695), ('2008-09', 'NSW', 800.9, 587.5, 131.6, 54.7, 7408540, 530532), ('2008-09', 'VIC', 695.3, 432.9, 273.5, 33.6, 5371934, 368579), ('2008-09', 'QLD', 629.2, 469.5, 187.9, 77.4, 4328771, 284526)]

# %% [markdown]
# ### Use the fetchall() function to return all the results.

# %%
sql = '''
SELECT * FROM AUS_energy;
'''
cur.execute(sql)
all_results = cur.fetchall()
print(all_results)
# Out:
# [('2008-09', 'WA', 132.9, 294.3, 474.7, 15.6, 2240250, 244695), ('2008-09', 'NSW', 800.9, 587.5, 131.6, 54.7, 7408540, 530532), ('2008-09', 'VIC', 695.3, 432.9, 273.5, 33.6, 5371934, 368579), ('2008-09', 'QLD', 629.2, 469.5, 187.9, 77.4, 4328771, 284526), ('2008-09', 'SA', 80.2, 120.2, 134.0, 21.2, 1608902, 100174), ('2008-09', 'TAS', 12.4, 41.6, 11.2, 37.1, 504353, 28165), ('2008-09', 'NT', '', 54.8, 39.9, 0.4, 226027, 19562), ('2009-10', 'WA', 125.6, 290.0, 474.9, 14.6, 2290845, 259326), ('2009-10', 'NSW', 771.8, 638.9, 148.7, 63.8, 7506058, 539670), ('2009-10', 'VIC', 688.7, 448.4, 263.5, 36.0, 5461101, 372276), ('2009-10', 'QLD', 547.5, 466.9, 195.8, 107.4, 4404744, 290556), ('2009-10', 'SA', 79.7, 120.5, 119.5, 20.4, 1627322, 102303), ('2009-10', 'TAS', 11.5, 41.5, 13.6, 40.0, 508847, 28402), ('2009-10', 'NT', '', 51.9, 42.0, 0.5, 229778, 19469), ('2010-11', 'WA', 130.6, 341.5, 494.9, 15.3, 2353409, 271336), ('2010-11', 'NSW', 732.2, 685.0, 146.5, 68.6, 7586514, 550617), ('2010-
# ...

# %% [markdown]
# ### Read Data Set
#
# Pandas use the pandas package to read a SQLite database

# %%
sql='''
SELECT * from AUS_energy;
'''
# Load the data into a DataFrame
asus_engy_df = pd.read_sql_query(sql, connection)

# %% [markdown]
# ### Display DataSet

# %%
asus_engy_df.head()
# Out:
#       Year State Coal (PJ)  Oil (PJ)  Gas (PJ)  Renewables (PJ)  Population  \
# 0  2008-09    WA     132.9     294.3     474.7             15.6     2240250
# 1  2008-09   NSW     800.9     587.5     131.6             54.7     7408540
# 2  2008-09   VIC     695.3     432.9     273.5             33.6     5371934
# 3  2008-09   QLD     629.2     469.5     187.9             77.4     4328771
# 4  2008-09    SA      80.2     120.2     134.0             21.2     1608902
#
#    GSP ($ million)
# 0           244695
# 1           530532
# 2           368579
# 3           284526
# 4           100174

# %%
asus_engy_df
# Out:
#        Year State Coal (PJ)  Oil (PJ)  Gas (PJ)  Renewables (PJ)  Population  \
# 0   2008-09    WA     132.9     294.3     474.7             15.6     2240250
# 1   2008-09   NSW     800.9     587.5     131.6             54.7     7408540
# 2   2008-09   VIC     695.3     432.9     273.5             33.6     5371934
# 3   2008-09   QLD     629.2     469.5     187.9             77.4     4328771
# 4   2008-09    SA      80.2     120.2     134.0             21.2     1608902
# ..      ...   ...       ...       ...       ...              ...         ...
# 93  2021-22   VIC     410.7     410.0     237.5            105.2     6625964
# 94  2021-22   QLD     485.6     504.7     305.7            143.0     5320496
# 95  2021-22    SA      25.9     141.6      80.2             48.3     1821200
# 96  2021-22   TAS       8.8      39.9       7.1             48.1      571013
# 97  2021-22    NT                37.6     110.6              1.6      250219
#
#     GSP ($ million)
# 0            244695
# ...

# %% [markdown]
# ### Display Data Types

# %%
# Check data types
asus_engy_df.dtypes
# Out:
# Year                object
# State               object
# Coal (PJ)           object
# Oil (PJ)           float64
# Gas (PJ)           float64
# Renewables (PJ)    float64
# Population           int64
# GSP ($ million)      int64
# dtype: object

# %% [markdown]
# The dataset provides information with the following columns: Year (object): The year of the data record, stored as a string. State (object): The state for which the data is recorded, stored as a string. Coal (PJ) (object): The energy consumption from coal, stored as a string. Oil (PJ) (float64): The energy consumption from oil, stored as a floating-point number. Gas (PJ) (float64): The energy consumption from gas, stored as a floating-point number. Renewables (PJ) (float64): The energy consumption from renewable sources, stored as a floating-point number. Population (int64): The population of the state, stored as an integer. GSP ($ million) (int64): The Gross State Product in million dollars, stored as an integer.

# %%
asus_engy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             98 non-null     object
#  1   State            98 non-null     object
#  2   Coal (PJ)        98 non-null     object
#  3   Oil (PJ)         98 non-null     float64
#  4   Gas (PJ)         98 non-null     float64
#  5   Renewables (PJ)  98 non-null     float64
#  6   Population       98 non-null     int64
#  7   GSP ($ million)  98 non-null     int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 6.2+ KB

# %%
# Summary statistics of numerical columns
asus_engy_df.describe()
# Out:
#          Oil (PJ)    Gas (PJ)  Renewables (PJ)    Population  GSP ($ million)
# count   98.000000   98.000000        98.000000  9.800000e+01        98.000000
# mean   317.653061  204.587755        51.580612  3.424330e+06    266337.000000
# std    229.318224  179.205651        38.383143  2.769970e+06    209376.485897
# min     33.400000    6.600000         0.400000  2.260270e+05     19469.000000
# 25%     54.350000   81.675000        24.025000  5.502752e+05     33440.000000
# 50%    379.100000  144.700000        42.500000  2.548325e+06    301927.000000
# 75%    507.675000  263.600000        72.600000  5.622772e+06    390060.250000
# max    687.400000  692.600000       143.000000  8.622575e+06    706003.000000

# %% [markdown]
# ### Check Dataset Duplicate

# %%
# Check for duplicates based on all columns
asus_engy_df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 93    False
# 94    False
# 95    False
# 96    False
# 97    False
# Length: 98, dtype: bool

# %% [markdown]
# #### The dataset contains no duplicate values, as indicated by all entries in the series being False. This means each row in the dataset is unique.

# %% [markdown]
# ### Check Dataset Missing Value

# %%
# Check for missing values
asus_engy_df.isnull().head()
# Out:
#     Year  State  Coal (PJ)  Oil (PJ)  Gas (PJ)  Renewables (PJ)  Population  \
# 0  False  False      False     False     False            False       False
# 1  False  False      False     False     False            False       False
# 2  False  False      False     False     False            False       False
# 3  False  False      False     False     False            False       False
# 4  False  False      False     False     False            False       False
#
#    GSP ($ million)
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
# Check for missing values in each row
null_records =asus_engy_df.isnull().any(axis=1)

asus_engy_df[null_records]
# Out:
# Empty DataFrame
# Columns: [Year, State, Coal (PJ), Oil (PJ), Gas (PJ), Renewables (PJ), Population, GSP ($ million)]
# Index: []

# %% [markdown]
# ####  The dataset contains no missing values, as indicated by all entries in the series being False.

# %% [markdown]
# ### Check DataSet Class Distribution

# %%
# Calculate the count of superheroes by gender
state_counts = asus_engy_df['State'].value_counts()

state_counts
# Out:
# State
# WA     14
# NSW    14
# VIC    14
# QLD    14
# SA     14
# TAS    14
# NT     14
# Name: count, dtype: int64

# %%
# Calculate the count of superheroes by gender
state_counts = asus_engy_df['State'].value_counts()

state_counts
# Define a list of different colors for each bar
colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightsalmon', 'lightpink', 'lightgray', 'lightyellow']

# Create a bar chart to visualize the distribution
plt.figure(figsize=(8, 6))
plt.bar(state_counts.index, state_counts.values, color=colors)
plt.title('Distribution of State by Asus_Energy')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=0)

# Display the plot
plt.show()

# %% [markdown]
# #### The bar chart visualizes the distribution of states within the Asus_Energy dataset. Each bar represents a different state with a unique color, making it easy to distinguish between them. The chart shows that each state—WA, NSW, VIC, QLD, SA, TAS, and NT—has an equal count of 14 entries in the dataset. This even distribution suggests that the dataset is balanced in terms of the representation of each state. The use of different colors enhances the visual appeal and helps in quickly identifying the states.

# %% [markdown]
# ##  Group-A Q1: Compute and visualize the total energy consumption for each state.

# %%
def preprocess_data(df):
    """Preprocess the data by converting columns to numeric types and calculating additional metrics."""
    df['Coal (PJ)'] = pd.to_numeric(df['Coal (PJ)'], errors='coerce')
    df['Oil (PJ)'] = pd.to_numeric(df['Oil (PJ)'], errors='coerce')
    df['Gas (PJ)'] = pd.to_numeric(df['Gas (PJ)'], errors='coerce')
    df['Renewables (PJ)'] = pd.to_numeric(df['Renewables (PJ)'], errors='coerce')
    df['Population'] = pd.to_numeric(df['Population'], errors='coerce')
    df['GSP ($ million)'] = pd.to_numeric(df['GSP ($ million)'], errors='coerce')

    df['Total Energy (PJ)'] = df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum(axis=1)
    df['Energy per Capita (GJ)'] = (df['Total Energy (PJ)'] * 1000) / df['Population']
    df['Energy Intensity (GJ/$ million)'] = (df['Total Energy (PJ)'] * 1000) / df['GSP ($ million)']
    df['Energy Productivity ($ million/PJ)'] = df['GSP ($ million)'] / df['Total Energy (PJ)']

    return df

# %%
# Preprocess the data
asus_engy_df = preprocess_data(asus_engy_df)

# %%
# Convert the 'Coal (PJ)' column to numeric
asus_engy_df['Coal (PJ)'] = pd.to_numeric(asus_engy_df['Coal (PJ)'], errors='coerce')

# Function to visualize total energy consumption by state
def visualize_total_energy_by_state(df):
    """Visualize the total energy consumption for each state."""
    energy_columns = ['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']

    # Ensure all energy columns are numeric
    for column in energy_columns:
        df[column] = pd.to_numeric(df[column], errors='coerce')

    total_energy_state = df.groupby('State')[energy_columns].sum()

    ax = total_energy_state.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')
    ax.set_title('Total Energy Consumption by State', fontsize=16)
    ax.set_xlabel('State', fontsize=14)
    ax.set_ylabel('Energy Consumption (PJ)', fontsize=14)
    ax.legend(title='Energy Source', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()


# Visualize total energy consumption by state
visualize_total_energy_by_state(asus_engy_df)

# %%
def visualize_total_energy_by_state(df):
    """Compute and visualize the total energy consumption for each state."""
    total_energy_state = df.groupby('State')['Total Energy (PJ)'].sum()
    plt.figure(figsize=(10, 6))
    total_energy_state.plot(kind='bar', color='skyblue')
    plt.title('Total Energy Consumption by State')
    plt.xlabel('State')
    plt.ylabel('Total Energy Consumption (PJ)')
    for index, value in enumerate(total_energy_state):
        plt.text(index, value, f'{value:.2f}', ha='center', va='bottom')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##  Group-A Q2: Compute and visualize the total energy consumption by fuel type.

# %%
# Compute the total energy consumption by fuel type
total_energy_by_fuel = asus_engy_df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()


# Bar chart for total energy consumption by fuel type
plt.figure(figsize=(10, 6))
ax = total_energy_by_fuel.plot(kind='bar', color=['purple', 'blue', 'green', 'yellow'])
plt.title('Total Energy Consumption by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Total Energy Consumption (PJ)')
plt.xticks(rotation=0)

# Adding value labels on the bars
for i in ax.containers:
    ax.bar_label(i, label_type='edge')

plt.tight_layout()
plt.show()

# %%
# Pie chart for total energy consumption by fuel type
plt.figure(figsize=(8, 8))
plt.pie(total_energy_by_fuel, labels=total_energy_by_fuel.index, autopct='%1.1f%%', colors=['purple', 'blue', 'green', 'yellow'])
plt.title('Total Energy Consumption by Fuel Type')
plt.tight_layout()
plt.show()

# %%
# Function to visualize total energy consumption by fuel type
def visualize_total_energy_by_fuel_type(df):
    """Visualize the total energy consumption by fuel type."""
    # Ensure the columns are of numeric type
    df['Coal (PJ)'] = pd.to_numeric(df['Coal (PJ)'], errors='coerce')
    df['Oil (PJ)'] = pd.to_numeric(df['Oil (PJ)'], errors='coerce')
    df['Gas (PJ)'] = pd.to_numeric(df['Gas (PJ)'], errors='coerce')
    df['Renewables (PJ)'] = pd.to_numeric(df['Renewables (PJ)'], errors='coerce')

    # Sum the total energy consumption by fuel type
    total_energy_fuel = df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()

    # Pie chart for total energy consumption by fuel type
    plt.figure(figsize=(8, 6))
    total_energy_fuel.plot(kind='pie', autopct='%1.1f%%', colors=['purple', 'blue', 'green', 'yellow'])
    plt.title('Total Energy Consumption by Fuel Type')
    plt.ylabel('')
    plt.tight_layout()
    plt.show()

# Assuming 'asus_engy_df' is the DataFrame containing the data
visualize_total_energy_by_fuel_type(asus_engy_df)

# %%
def visualize_total_energy_by_fuel_type(df):
    """Compute and visualize the total energy consumption by fuel type."""
    total_energy_fuel = df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()
    plt.figure(figsize=(10, 6))
    total_energy_fuel.plot(kind='bar', color=['purple', 'blue', 'green', 'yellow'])
    plt.title('Total Energy Consumption by Fuel Type')
    plt.xlabel('Fuel Type')
    plt.ylabel('Total Energy Consumption (PJ)')
    for index, value in enumerate(total_energy_fuel):
        plt.text(index, value, f'{value:.2f}', ha='center', va='bottom')
    plt.tight_layout()
    plt.show()

# %%
visualize_total_energy_by_fuel_type(asus_engy_df)

# %% [markdown]
# ##  Group-A Q3: Analyse and plot the total energy consumption fuel types for each year.

# %%
# Function to analyze and plot total energy consumption by fuel types for each year
def visualize_energy_by_fuel_type_per_year(df):
    """Analyze and plot total energy consumption by fuel types for each year."""
    # Ensure the columns are of numeric type
    df['Coal (PJ)'] = pd.to_numeric(df['Coal (PJ)'], errors='coerce')
    df['Oil (PJ)'] = pd.to_numeric(df['Oil (PJ)'], errors='coerce')
    df['Gas (PJ)'] = pd.to_numeric(df['Gas (PJ)'], errors='coerce')
    df['Renewables (PJ)'] = pd.to_numeric(df['Renewables (PJ)'], errors='coerce')

    # Group by year and sum the energy consumption by fuel type
    energy_per_year = df.groupby('Year')[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()

    # Define custom colors for each line
    colors = ['purple', 'blue', 'green', 'orange']

    # Plot the data as a line chart
    plt.figure(figsize=(12, 8))
    for i, column in enumerate(energy_per_year.columns):
        plt.plot(energy_per_year.index, energy_per_year[column], marker='o', color=colors[i], label=column)
        # Add value labels to each point
        for x, y in zip(energy_per_year.index, energy_per_year[column]):
            plt.text(x, y, f'{y:.1f}', fontsize=9, ha='right', va='bottom')

    plt.title('Total Energy Consumption by Fuel Type per Year')
    plt.xlabel('Year')
    plt.ylabel('Total Energy Consumption (PJ)')
    plt.legend(title='Fuel Type', loc='upper left')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Assuming 'asus_engy_df' is the DataFrame containing the data
visualize_energy_by_fuel_type_per_year(asus_engy_df)

# %%
def visualize_energy_by_fuel_type_per_year(df):
    """Analyze and plot total energy consumption by fuel types for each year."""
    # Group by year and sum the energy consumption for each fuel type
    energy_per_year = df.groupby('Year')[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()

    # Plot the data with markers
    ax = energy_per_year.plot(kind='line', marker='o', figsize=(10, 7))
    ax.set_title('Total Energy Consumption by Fuel Type per Year', fontsize=16)
    ax.set_xlabel('Year', fontsize=14)
    ax.set_ylabel('Energy Consumption (PJ)', fontsize=14)

    # Adjust the legend position to upper left
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, ['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)'], loc='upper right', title='Fuel Type', title_fontsize='13', fontsize='12')

    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Assuming 'asus_energy_df' is the DataFrame containing the data
visualize_energy_by_fuel_type_per_year(asus_engy_df)

# %%
def visualize_energy_by_fuel_type_per_year(df):
    """Analyze and plot total energy consumption by fuel types for each year."""
    energy_per_year = df.groupby('Year')[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()
    plt.figure(figsize=(12, 8))
    for column in energy_per_year.columns:
        plt.plot(energy_per_year.index, energy_per_year[column], marker='o', label=column)
        for x, y in zip(energy_per_year.index, energy_per_year[column]):
            plt.text(x, y, f'{y:.2f}', fontsize=9)
    plt.title('Total Energy Consumption by Fuel Type per Year')
    plt.xlabel('Year')
    plt.ylabel('Total Energy Consumption (PJ)')
    plt.legend(title='Fuel Type', loc='upper left')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
visualize_energy_by_fuel_type_per_year(asus_engy_df)

# %% [markdown]
# ##  Group-A Q4: Analyse and visualize the total energy consumption for each state for each

# %%
# Ensure the columns are of numeric type
asus_engy_df['Coal (PJ)'] = pd.to_numeric(asus_engy_df['Coal (PJ)'], errors='coerce')
asus_engy_df['Oil (PJ)'] = pd.to_numeric(asus_engy_df['Oil (PJ)'], errors='coerce')
asus_engy_df['Gas (PJ)'] = pd.to_numeric(asus_engy_df['Gas (PJ)'], errors='coerce')
asus_engy_df['Renewables (PJ)'] = pd.to_numeric(asus_engy_df['Renewables (PJ)'], errors='coerce')

# Calculate the total energy consumption
asus_engy_df['Total Energy (PJ)'] = asus_engy_df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum(axis=1)

# Group by year and state, then sum the total energy consumption
energy_per_year_state = asus_engy_df.groupby(['Year', 'State'])['Total Energy (PJ)'].sum().unstack()

# Plot the data as a stacked bar chart
energy_per_year_state.plot(kind='bar', stacked=True, figsize=(14, 8))
plt.title('Total Energy Consumption by State per Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Energy Consumption (PJ)', fontsize=14)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# If you want to include individual values on the bars, you can use the following code:

# Plot the data as a stacked bar chart
ax = energy_per_year_state.plot(kind='bar', stacked=True, figsize=(14, 8))
plt.title('Total Energy Consumption by State per Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Energy Consumption (PJ)', fontsize=14)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')

# Add values on the bars
for container in ax.containers:
    ax.bar_label(container, label_type='center')

plt.tight_layout()
plt.show()

# %%
# Ensure the columns are of numeric type
asus_engy_df['Coal (PJ)'] = pd.to_numeric(asus_engy_df['Coal (PJ)'], errors='coerce')
asus_engy_df['Oil (PJ)'] = pd.to_numeric(asus_engy_df['Oil (PJ)'], errors='coerce')
asus_engy_df['Gas (PJ)'] = pd.to_numeric(asus_engy_df['Gas (PJ)'], errors='coerce')
asus_engy_df['Renewables (PJ)'] = pd.to_numeric(asus_engy_df['Renewables (PJ)'], errors='coerce')

## Calculate the total energy consumption
asus_engy_df['Total Energy (PJ)'] = asus_engy_df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum(axis=1)

# Group by state and year, then sum the total energy consumption
energy_per_state_year = asus_engy_df.groupby(['State', 'Year'])['Total Energy (PJ)'].sum().unstack()

# List of states to plot
states = ['NSW', 'VIC', 'QLD', 'WA', 'SA', 'TAS', 'NT']

fig, axes = plt.subplots(nrows=len(states), ncols=1, figsize=(14, 20), constrained_layout=True)
axes = axes.flatten()

for ax, state in zip(axes, states):
    energy_per_state_year.loc[state].plot(kind='bar', ax=ax, color='skyblue')
    ax.set_title(f'Total Energy Consumption for {state}', fontsize=14)
    ax.set_xlabel('Year', fontsize=12)
    ax.set_ylabel('Total Energy Consumption (PJ)', fontsize=12)
    ax.set_xticklabels(energy_per_state_year.columns, rotation=45)

    # Adding value labels to the bars
    for container in ax.containers:
        ax.bar_label(container, label_type='edge')

plt.suptitle('Total Energy Consumption by State per Year', fontsize=16)
plt.show()

# %% [markdown]
# ## Group-B Q5: Analyse and visualise the total energy consumption for each state, broken down by fuel type.

# %%
# Ensure the columns are of numeric type
asus_engy_df['Coal (PJ)'] = pd.to_numeric(asus_engy_df['Coal (PJ)'], errors='coerce')
asus_engy_df['Oil (PJ)'] = pd.to_numeric(asus_engy_df['Oil (PJ)'], errors='coerce')
asus_engy_df['Gas (PJ)'] = pd.to_numeric(asus_engy_df['Gas (PJ)'], errors='coerce')
asus_engy_df['Renewables (PJ)'] = pd.to_numeric(asus_engy_df['Renewables (PJ)'], errors='coerce')

# Calculate the total energy consumption
asus_engy_df['Total Energy (PJ)'] = asus_engy_df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum(axis=1)

# Group by state and sum the energy consumption for each fuel type
energy_per_state = asus_engy_df.groupby('State')[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()

# Plot the data as a stacked bar chart
energy_per_state.plot(kind='bar', stacked=True, figsize=(14, 8), color=['purple', 'blue', 'green', 'orange'])
plt.title('Total Energy Consumption by State and Fuel Type', fontsize=16)
plt.xlabel('State', fontsize=14)
plt.ylabel('Total Energy Consumption (PJ)', fontsize=14)
plt.legend(title='Fuel Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# If you want to include individual values on the bars, you can use the following code:
fig, ax = plt.subplots(figsize=(14, 8))
energy_per_state.plot(kind='bar', stacked=True, ax=ax, color=['purple', 'blue', 'green', 'orange'])
plt.title('Total Energy Consumption by State and Fuel Type', fontsize=16)
plt.xlabel('State', fontsize=14)
plt.ylabel('Total Energy Consumption (PJ)', fontsize=14)
plt.legend(title='Fuel Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Adding value labels to the bars
for container in ax.containers:
    ax.bar_label(container, label_type='center')

plt.tight_layout()
plt.show()

# %%
# Calculate the total energy consumption
asus_engy_df['Total Energy (PJ)'] = asus_engy_df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum(axis=1)

# Group by state and sum the energy consumption for each fuel type
energy_per_state = asus_engy_df.groupby('State')[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()

# Plot the data as a stacked bar chart
fig, ax = plt.subplots(figsize=(14, 8))
energy_per_state.plot(kind='bar', stacked=True, ax=ax, color=['purple', 'blue', 'green', 'orange'])
plt.title('Total Energy Consumption by State and Fuel Type', fontsize=16)
plt.xlabel('State', fontsize=14)
plt.ylabel('Total Energy Consumption (PJ)', fontsize=14)
plt.legend(title='Fuel Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Adding value labels to the bars
for container in ax.containers:
    ax.bar_label(container, label_type='center')

plt.tight_layout()
plt.show()

# %%
def visualize_total_energy_by_state_and_fuel_type(df):
    """Analyze and visualize the total energy consumption for each state, broken down by fuel type."""
    energy_per_state = df.groupby('State')[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum()
    ax = energy_per_state.plot(kind='bar', stacked=True, figsize=(14, 8), color=['purple', 'blue', 'green', 'yellow'])
    plt.title('Total Energy Consumption by State and Fuel Type')
    plt.xlabel('State')
    plt.ylabel('Total Energy Consumption (PJ)')
    plt.legend(title='Fuel Type')
    plt.tight_layout()
    plt.show()

# %%
visualize_total_energy_by_state_and_fuel_type(asus_engy_df)

# %% [markdown]
# ## Group-B Q6: Analyse the per capita energy consumption for each state for each year and create a corresponding visualization.

# %%
# Calculate the total energy consumption
asus_engy_df['Total Energy (PJ)'] = asus_engy_df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum(axis=1)

# Calculate the per capita energy consumption
asus_engy_df['Per Capita Energy (PJ)'] = asus_engy_df['Total Energy (PJ)'] / asus_engy_df['Population']

# Group by state and year to sum the per capita energy consumption
energy_per_state_year = asus_engy_df.groupby(['State', 'Year'])['Per Capita Energy (PJ)'].sum().unstack()

# Define custom colors for each state
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown', 'pink']

# Plot the data as a line chart with custom colors
plt.figure(figsize=(14, 8))
for state, color in zip(energy_per_state_year.index, colors):
    plt.plot(energy_per_state_year.columns, energy_per_state_year.loc[state], marker='o', label=state, color=color)

plt.title('Per Capita Energy Consumption by State per Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Per Capita Energy Consumption (PJ)', fontsize=14)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Calculate the total energy consumption
asus_engy_df['Total Energy (PJ)'] = asus_engy_df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum(axis=1)

# Calculate the per capita energy consumption
asus_engy_df['Per Capita Energy (PJ)'] = asus_engy_df['Total Energy (PJ)'] / asus_engy_df['Population']

# Group by state and year to sum the per capita energy consumption
energy_per_state_year = asus_engy_df.groupby(['State', 'Year'])['Per Capita Energy (PJ)'].sum().unstack()

# Define custom colors for each state
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown', 'pink']

# Plot the data as a line chart with custom colors and value labels
plt.figure(figsize=(14, 8))
for state, color in zip(energy_per_state_year.index, colors):
    plt.plot(energy_per_state_year.columns, energy_per_state_year.loc[state], marker='o', label=state, color=color)
    # Add value labels to each point
    for x, y in zip(energy_per_state_year.columns, energy_per_state_year.loc[state]):
        plt.text(x, y, f'{y:.5f}', fontsize=9, ha='right', va='bottom')

plt.title('Per Capita Energy Consumption by State per Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Per Capita Energy Consumption (PJ)', fontsize=14)
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def visualize_per_capita_energy_by_state_per_year(df):
    """Analyze the per capita energy consumption for each state for each year and create a corresponding visualization."""
    df['Per Capita Energy (PJ)'] = df['Total Energy (PJ)'] / df['Population']
    energy_per_state_year = df.groupby(['State', 'Year'])['Per Capita Energy (PJ)'].sum().unstack()
    plt.figure(figsize=(14, 8))
    for state in energy_per_state_year.index:
        plt.plot(energy_per_state_year.columns, energy_per_state_year.loc[state], marker='o', label=state)
        for x, y in zip(energy_per_state_year.columns, energy_per_state_year.loc[state]):
            plt.text(x, y, f'{y:.6f}', fontsize=9)
    plt.title('Per Capita Energy Consumption by State per Year')
    plt.xlabel('Year')
    plt.ylabel('Per Capita Energy Consumption (PJ)')
    plt.legend(title='State', loc='upper left')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
visualize_per_capita_energy_by_state_per_year(asus_engy_df)

# %% [markdown]
# ## Group-C Q8: Analyse the energy intensity, defined as energy consumption per unit of GSP, for each state annually and chart these figures.

# %%
import pandas as pd
import matplotlib.pyplot as plt

def visualize_energy_intensity(df):
   # Calculate total energy consumption
    df['Total Energy (PJ)'] = df[['Coal (PJ)', 'Oil (PJ)', 'Gas (PJ)', 'Renewables (PJ)']].sum(axis=1)

    # Calculate energy intensity
    df['Energy Intensity (GJ/$ million)'] = (df['Total Energy (PJ)'] * 1000) / df['GSP ($ million)']

    # Create pivot table for plotting
    energy_intensity = df.pivot_table(values='Energy Intensity (GJ/$ million)', index='Year', columns='State')

    # Define colors for each state
    colors = {
        'NSW': 'blue',
        'NT': 'orange',
        'QLD': 'green',
        'SA': 'red',
        'TAS': 'purple',
        'VIC': 'brown',
        'WA': 'pink'
    }

    # Plot the data with custom colors
    plt.figure(figsize=(12, 8))
    for state in energy_intensity.columns:
        plt.plot(energy_intensity.index, energy_intensity[state], marker='o', color=colors[state], label=state)

    plt.title('Energy Intensity by State per Year', fontsize=16)
    plt.xlabel('Year', fontsize=14)
    plt.ylabel('Energy Intensity (GJ/$ million)', fontsize=14)
    plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Assuming 'asus_energy_df' is the DataFrame containing the data
visualize_energy_intensity(asus_engy_df)
